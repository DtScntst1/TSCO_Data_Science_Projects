# %% [markdown]
# Soru: Bir sayının tek mi çift mi olduğunu bulan programın akış diyagramını çizin

# %%
       +----------------+
       |     Başla      |
       +----------------+
               |
               v
       +----------------+
       | Kullanıcıdan    |
       |  bir sayı al    |
       +----------------+
               |
               v
       +----------------+
       |  Sayıyı 2'ye   |
       |  böl ve kalan   |
       +----------------+
               |
        +------|-------+
        |              |
        v              v
+---------------+  +---------------+
| Kalan = 0 mi? |  | Kalan != 0 mi? |
+---------------+  +---------------+
        |              |
       Evet           Hayır
        |              |
        v              v
+---------------+  +---------------+
| Çift sayıdır  |  | Tek sayıdır   |
+---------------+  +---------------+
        |              |
        v              v
+----------------+
|  Sonucu göster  |
+----------------+
        |
        v
+----------------+
|      Bitir      |
+----------------+

# %% [markdown]
# Soru: Bir sayının asal olup olmadığını belirleyen bir programın akış diyagramını çizin.

# %% [markdown]
#        +----------------+
#        |     Başla      |
#        +----------------+
#                |
#                v
#        +----------------+
#        | Kullanıcıdan    |
#        |  bir sayı al    |
#        +----------------+
#                |
#                v
#        +----------------+
#        | Sayıyı kontrol  |
#        | (Sayı > 1 mi?)  |
#        +----------------+
#                |
#         +------|-------+
#         |              |
#        Hayır           Evet
#         |              |
#         v              v
# +---------------+  +---------------+
# |  Asal değildir | |  i = 2       |
# +---------------+  +---------------+
#                        |
#                        v
#        +-----------------------------+
#        | i, sayının kareköküne kadar |
#        | kontrol et                  |
#        +-----------------------------+
#                        |
#             +----------|----------+
#             |                     |
#           Evet                   Hayır
#             |                     |
#             v                     v
# +----------------+      +----------------+
# |     Asaldır    |      |  sayı % i == 0?|
# +----------------+      +----------------+
#             |                     |
#             |                     +----------+
#             |                                |
#             |                        Hayır    |
#             |                          |       |
#             |                          v       v
#             |               +----------------+   |
#             |               |     i = i + 1  |   |
#             |               +----------------+   |
#             |                     |               |
#             |                     +---------------+
#             |                          |
#             +--------------------------+
#                        |
#                        v
#                 +----------------+
#                 |      Bitir      |
#                 +----------------+

# %% [markdown]
# Soru: Bir öğrencinin sınav notlarına göre harf notu belirleyen bir programın akış diyagramını çizin.

# %%
       +----------------+
       |     Başla      |
       +----------------+
               |
               v
       +----------------+
       | Kullanıcıdan    |
       |  bir sınav notu |
       |  al (0-100)     |
       +----------------+
               |
               v
       +----------------+
       |  Notu kontrol   |
       | (Not < 0 veya   |
       |   Not > 100 mi?)|
       +----------------+
               |
        +------|-------+
        |              |
       Evet           Hayır
        |              |
        v              v
+----------------+  +-----------------+
|  Geçersiz not  |  |  Notu değerlendir|
|   Sonucu göster |  +-----------------+
+----------------+              |
                               +----------------+
                               |  Not ≥ 90 mi?  |
                               +----------------+
                                      |
                                +-----|------+
                                |            |
                               Evet         Hayır
                                |            |
                                v            v
                      +----------------+  +----------------+
                      |  Harf Notu: A |  |  Not ≥ 80 mi?  |
                      +----------------+  +----------------+
                                             |
                                       +-----|------+
                                       |            |
                                      Evet         Hayır
                                       |            |
                                       v            v
                             +----------------+  +----------------+
                             |  Harf Notu: B |  |  Not ≥ 70 mi?  |
                             +----------------+  +----------------+
                                                    |
                                              +-----|------+
                                              |            |
                                             Evet         Hayır
                                              |            |
                                              v            v
                                    +----------------+  +----------------+
                                    |  Harf Notu: C |  |  Not ≥ 60 mi?  |
                                    +----------------+  +----------------+
                                                       |
                                                 +-----|------+
                                                 |            |
                                                Evet         Hayır
                                                 |            |
                                                 v            v
                                       +----------------+  +----------------+
                                       |  Harf Notu: D |  |  Harf Notu: F  |
                                       +----------------+  +----------------+
                                                 |
                                                 v
                                       +----------------+
                                       | Harf notunu göster |
                                       +----------------+
                                                 |
                                                 v
                                       +----------------+
                                       |      Bitir      |
                                       +----------------+
